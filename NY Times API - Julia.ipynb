# %%
import pandas as pd
import requests
import json

#api key
api_key = "S8zHEEG45YRfqFuF9SEuVmsvniB9lhtO"
# resource url
url = "https://api.nytimes.com/svc/archive/v1/2012/2.json?&query=smoking&api-key= " + api_key
r = requests.get(url)

# get json
request_data= r.json()
# filter to get required data
data=request_data['response']['docs']

# create a dataframe
df = pd.DataFrame(data)
df.head()
# Out:
#                                             abstract  \
# 0  A free iPhone app called Pozzle lets you creat...
# 1  The Opera Orchestra of New York performed “Rie...
# 2  The latest campaign filings showed a crucial s...
# 3  Of the record 40,000 people in New York City’s...
# 4  A deal with private bondholders to reduce Gree...
#
#                                              web_url  \
# 0  https://gadgetwise.blogs.nytimes.com/2012/01/3...
# 1  https://www.nytimes.com/2012/02/01/arts/music/...
# 2  https://www.nytimes.com/2012/02/01/us/politics...
# 3  https://www.nytimes.com/2012/02/05/nyregion/or...
# 4  https://www.nytimes.com/2012/02/03/business/gl...
#
#                                              snippet  \
# 0  A free iPhone app called Pozzle lets you creat...
# 1  The Opera Orchestra of New York performed “Rie...
# 2  The latest campaign filings showed a crucial s...
# 3  Of the record 40,000 people in New York City’s...
# 4  A deal with private bondholders to reduce Gree...
#
#                                       lead_paragraph              source  \
# 0  Maybe you have a problem getting friends to me...  The New York Times
# 1  “Rienzi,” Wagner’s third opera, is seldom perf...  The New York Times
# 2  Close to 60 corporations and wealthy individua...  The New York Times
# 3  ON the sixth day she was homeless, Tonya Lewis...  The New York Times
# 4  FRANKFURT — Private-sector creditors appeared ...  The New York Times
#
#                                           multimedia  \
# 0                                                 []
# 1  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4                                                 []
#
#                                             headline  \
# 0  {'main': 'A Groupon for Your Dinner Party', 'k...
# 1  {'main': 'An Early Wagner, but With All the Tr...
# 2  {'main': 'G.O.P. Donors Showing Thirst to Oust...
# 3  {'main': 'Homeless Families, Cloaked in Normal...
# 4  {'main': 'Greek Debt Talks Progress, but Budge...
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Computers and t...
# 1  [{'name': 'organizations', 'value': 'Opera Orc...
# 2  [{'name': 'subject', 'value': 'Political Actio...
# 3  [{'name': 'subject', 'value': 'Families and Fa...
# 4  [{'name': 'subject', 'value': 'Credit and Debt...
#
#                    pub_date document_type  ...  section_name  subsection_name  \
# 0  2012-02-01T00:21:28+0000       article  ...    Technology    Personal Tech
# 1  2012-02-01T00:07:10+0000       article  ...          Arts            Music
# 2  2012-02-01T02:12:20+0000       article  ...          U.S.         Politics
# 3  2012-02-03T18:02:40+0000       article  ...      New York              NaN
# 4  2012-02-02T20:11:24+0000       article  ...  Business Day  Global Business
#
#                                               byline type_of_material  \
# 0  {'original': 'By Roy Furchgott', 'person': [{'...             News
# 1  {'original': 'By Anthony Tommasini', 'person':...           Review
# 2  {'original': 'By Nicholas Confessore and Micha...             News
# 3  {'original': 'By Alan Feuer', 'person': [{'fir...             News
# 4  {'original': 'By Jack Ewing and Niki Kitsanton...             News
#
#                                                  _id word_count  \
# 0  nyt://article/0073a7f1-16d5-577f-b2e7-316b0e46...        493
# 1  nyt://article/007d7c68-99d4-58d7-87b0-30954c7e...        609
# 2  nyt://article/007ee2c3-2d85-5324-816b-ff7c8291...       1281
# 3  nyt://article/008857c6-23a9-5258-8d78-3741a789...       2353
# 4  nyt://article/009e2339-4846-5807-b246-55b98e28...        627
#
#                                                  uri print_section print_page  \
# 0  nyt://article/0073a7f1-16d5-577f-b2e7-316b0e46...           NaN        NaN
# 1  nyt://article/007d7c68-99d4-58d7-87b0-30954c7e...             C          4
# 2  nyt://article/007ee2c3-2d85-5324-816b-ff7c8291...             A          1
# 3  nyt://article/008857c6-23a9-5258-8d78-3741a789...            MB          1
# 4  nyt://article/009e2339-4846-5807-b246-55b98e28...             A          6
#
#   slideshow_credits
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 21 columns]
